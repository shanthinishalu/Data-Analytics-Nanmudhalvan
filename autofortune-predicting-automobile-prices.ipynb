# %% [markdown]
# # Histograms, KDE Plots and Rug Plots
#
# **Abid Ali**
#
# Email: [abdsoftfsd@gmail.com](mailto:abdsoftfsd@gmail.com)
#
# Skype: abd.soft

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from numpy import nan

# %%
automobile_data = pd.read_csv('/kaggle/input/automobile-dataset/Automobile_data.csv')
automobile_data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
automobile_data.shape
# Out:
# (205, 26)

# %%
automobile_data['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
automobile_data['normalized-losses'].replace(['?'], [nan], inplace=True)

# %%
automobile_data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
automobile_data.dropna(inplace=True)

# %%
automobile_data.shape
# Out:
# (164, 26)

# %%
automobile_data['bore'].value_counts()
# Out:
# 3.62    20
# 3.19    15
# 3.15    15
# 2.97    12
# 3.03    10
# 3.78     7
# 2.91     7
# 3.27     6
# 3.31     6
# 3.05     6
# 3.43     6
# 3.58     5
# 3.54     5
# 3.39     5
# 3.01     4
# 3.35     4
# 3.46     4
# ?        4
# 3.7      3
# 3.17     3
# 3.5      2
# 3.24     2
# 3.33     2
# 3.13     1
# 3.6      1
# 2.92     1
# 3.63     1
# 3.94     1
# 2.54     1
# 3.08     1
# 3.61     1
# 3.34     1
# 3.76     1
# 2.99     1
# Name: bore, dtype: int64

# %%
# in our case, we are not dealing with missing values here, we are exploring plots, so we can drop all "?" values.
automobile_data.replace(['?'], [nan], inplace=True)
automobile_data.dropna(inplace=True)

# %%
automobile_data.shape
# Out:
# (159, 26)

# %%
automobile_data.to_csv('/kaggle/working//automobiles_data_processed.csv', index=False)

# %%
plt.figure(figsize=(12, 8))

automobile_data['price'] = automobile_data['price'].astype(int)
automobile_data['horsepower'] = automobile_data['horsepower'].astype(int)
sns.histplot(automobile_data['price'], color='red', kde=True)
plt.title('Automobiles Data')
plt.show()

# %%
automobile_data['price']
# Out:
# 3      13950
# 4      17450
# 6      17710
# 8      23875
# 10     16430
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 159, dtype: int64

# %%
price_data = automobile_data['price']

plt.figure(figsize=(12, 8))
sns.kdeplot(price_data, color='blue')
plt.title('Automobile Data')
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.kdeplot(automobile_data['price'],
           color='blue')
sns.rugplot(x=automobile_data['price'], color='red')
plt.title('Automobile Data')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.rugplot(price_data.astype(int),
            height=0.5, color='blue', )

plt.title('Automobile Data')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.kdeplot(price_data.astype(int),
             fill=True, color='blue')

plt.title('Automobile Data')
plt.show()

# %%
automobile_data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower             int64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
price_data.head()
# Out:
# 3     13950
# 4     17450
# 6     17710
# 8     23875
# 10    16430
# Name: price, dtype: int64

# %%
automobile_data['horsepower']
# Out:
# 3      102
# 4      115
# 6      110
# 8      140
# 10     101
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 159, dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='horsepower', y='price', data=automobile_data, s=120)

plt.title('Automobile Data')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='horsepower', y='price', hue='num-of-cylinders', data=automobile_data, s=120)

plt.title('Automobile Data')
plt.show()

# %%
sns.regplot(x='horsepower', y='price', data=automobile_data)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
plt.figure(figsize=(12, 8))
sns.regplot(x='highway-mpg', y='price', data=automobile_data)

plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.jointplot(x='horsepower', y='price', data=automobile_data)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.jointplot(x='horsepower', y='price', kind='reg', data=automobile_data)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.set_theme(style='whitegrid')
sns.jointplot(x='horsepower', y='price', kind='kde', data=automobile_data)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.set_theme(style='whitegrid')
sns.jointplot(x='horsepower', y='price', kind='hex', data=automobile_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 6))

sns.kdeplot(x=automobile_data['horsepower'], y=automobile_data['price'], ax=ax)
sns.rugplot(x=automobile_data['horsepower'], color='limegreen', ax=ax)
sns.rugplot(y=automobile_data['price'], color='red', ax=ax)

plt.title('Automobile Data')
plt.show()
